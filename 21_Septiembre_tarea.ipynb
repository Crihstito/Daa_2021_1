# %% [markdown]
# <a href="https://colab.research.google.com/github/Crihstito/Daa_2021_1/blob/master/21_Septiembre_tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from time import time
def ejemplo1( n ):
    start_time = time()
    c = n + 1
    d = c * n
    e = n * n
    total = c + e - d
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)

for entrada in range (100,1001,100):
    ejemplo1(entrada)
# Out:
# Tiempo transcurrido: 0.0000007153 segundos.
# Tiempo transcurrido: 0.0000009537 segundos.
# Tiempo transcurrido: 0.0000011921 segundos.
# Tiempo transcurrido: 0.0000007153 segundos.
# Tiempo transcurrido: 0.0000004768 segundos.
# Tiempo transcurrido: 0.0000007153 segundos.
# Tiempo transcurrido: 0.0000002384 segundos.
# Tiempo transcurrido: 0.0000002384 segundos.
# Tiempo transcurrido: 0.0000004768 segundos.
# Tiempo transcurrido: 0.0000004768 segundos.

# %%
from time import time
def ejemplo2( n ):
    start_time = time()
    contador = 0
    for i in range( n ) :
        for j in range( n ) :
            contador += 1
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return contador

for entrada in range (100,1001,100):
    ejemplo2(entrada)
# Out:
# Tiempo transcurrido: 0.0004582405 segundos.
# Tiempo transcurrido: 0.0017616749 segundos.
# Tiempo transcurrido: 0.0040714741 segundos.
# Tiempo transcurrido: 0.0079002380 segundos.
# Tiempo transcurrido: 0.0138800144 segundos.
# Tiempo transcurrido: 0.0242307186 segundos.
# Tiempo transcurrido: 0.0316081047 segundos.
# Tiempo transcurrido: 0.0361132622 segundos.
# Tiempo transcurrido: 0.0418262482 segundos.
# Tiempo transcurrido: 0.0520591736 segundos.

# %%
from time import time

def ejemplo3( n ): # n=4
    start_time = time()
    x = n * 2 # x = 8
    y = 0   # y = 0
    for m in range( 100 ): #3
        y = x - n   # y = 4
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return y

for entrada in range (100,1001,100):
    ejemplo3(entrada)
# Out:
# Tiempo transcurrido: 0.0000047684 segundos.
# Tiempo transcurrido: 0.0000078678 segundos.
# Tiempo transcurrido: 0.0000085831 segundos.
# Tiempo transcurrido: 0.0000088215 segundos.
# Tiempo transcurrido: 0.0000092983 segundos.
# Tiempo transcurrido: 0.0000083447 segundos.
# Tiempo transcurrido: 0.0000085831 segundos.
# Tiempo transcurrido: 0.0000076294 segundos.
# Tiempo transcurrido: 0.0000076294 segundos.
# Tiempo transcurrido: 0.0000071526 segundos.

# %%
from time import time

def ejemplo4( n ):
    start_time = time()
    x = 3 * 3.1416 + n
    y = x + 3 * 3 - n
    z = x + y
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return z

for entrada in range (100,1001,100):
    ejemplo4(entrada)
# Out:
# Tiempo transcurrido: 0.0000011921 segundos.
# Tiempo transcurrido: 0.0000007153 segundos.
# Tiempo transcurrido: 0.0000004768 segundos.
# Tiempo transcurrido: 0.0000007153 segundos.
# Tiempo transcurrido: 0.0000007153 segundos.
# Tiempo transcurrido: 0.0000002384 segundos.
# Tiempo transcurrido: 0.0000002384 segundos.
# Tiempo transcurrido: 0.0000002384 segundos.
# Tiempo transcurrido: 0.0000004768 segundos.
# Tiempo transcurrido: 0.0000002384 segundos.

# %%
def ejemplo5( x ):
    start_time = time()
    n = 10
    for j in range( 0 , x , 1 ):
        n = j + n
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return n

for entrada in range (100,1001,100):
    ejemplo5( entrada )
# Out:
# Tiempo transcurrido: 0.0000081062 segundos.
# Tiempo transcurrido: 0.0000152588 segundos.
# Tiempo transcurrido: 0.0000195503 segundos.
# Tiempo transcurrido: 0.0000264645 segundos.
# Tiempo transcurrido: 0.0000383854 segundos.
# Tiempo transcurrido: 0.0000472069 segundos.
# Tiempo transcurrido: 0.0000793934 segundos.
# Tiempo transcurrido: 0.0000648499 segundos.
# Tiempo transcurrido: 0.0000731945 segundos.
# Tiempo transcurrido: 0.0000917912 segundos.

# %%
from time import time

def ejemplo6( n ):
    start_time = time()
    data=[[[1 for x in range(n)] for x in range(n)]
          for x in range(n)]
    suma = 0
    for d in range(n):
        for r in range(n):
            for c in range(n):
                suma += data[d][r][c]
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return suma
for entrada in range (100,1100,100):
    ejemplo6( entrada )
# Out:
# Tiempo transcurrido: 0.1940765381 segundos.
# Tiempo transcurrido: 1.0204997063 segundos.
# Tiempo transcurrido: 3.6444644928 segundos.
# Tiempo transcurrido: 9.3003125191 segundos.
# Tiempo transcurrido: 17.6446709633 segundos.
# Tiempo transcurrido: 32.0695917606 segundos.
# Tiempo transcurrido: 52.0522356033 segundos.
# Tiempo transcurrido: 76.8503561020 segundos.
# Tiempo transcurrido: 111.0883209705 segundos.
# Tiempo transcurrido: 154.6849162579 segundos.
